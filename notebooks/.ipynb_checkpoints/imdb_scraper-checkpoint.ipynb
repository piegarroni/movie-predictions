# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
# loading datasets and preliminary cleaning


metas=pd.read_csv('../../data/movies_meta.csv')
metas=metas.loc[metas['original_language']=='en']  # only english movies
metas=metas.drop(['production_countries', 'overview', 'tagline', 'belongs_to_collection', 'homepage', 'revenue', 'spoken_languages', 'video', 'homepage', "poster_path", 'production_companies'], axis=1)
print(metas.__len__())
# Out:
# 3608

# %%
ids=list(metas['imdb_id'])
print(ids)
# Out:
# ['tt0114709', 'tt0113497', 'tt0113189', 'tt0113627', 'tt0114746', 'tt0112637', 'tt0112818', 'tt0113442', 'tt0112697', 'tt0113855', 'tt0114369', 'tt0114148', 'tt0113419', 'tt0115683', 'tt0113537', 'tt0114660', 'tt0075314', 'tt0115645', 'tt0110647', 'tt0112442', 'tt0109093', 'tt0112495', 'tt0109370', 'tt0112851', 'tt0112864', 'tt0113464', 'tt0114781', 'tt0112508', 'tt0109758', 'tt0113198', 'tt0110057', 'tt0113360', 'tt0076759', 'tt0110367', 'tt0110365', 'tt0110428', 'tt0110516', 'tt0114151', 'tt0110932', 'tt0114214', 'tt0110907', 'tt0111149', 'tt0111454', 'tt0114852', 'tt0108550', 'tt0112435', 'tt0109040', 'tt0109444', 'tt0109484', 'tt0109506', 'tt0109450', 'tt0109830', 'tt0110213', 'tt0111686', 'tt0110475', 'tt0110478', 'tt0110622', 'tt0110950', 'tt0105226', 'tt0110997', 'tt0111693', 'tt0111742', 'tt0110455', 'tt0111301', 'tt0114047', 'tt0110027', 'tt0109305', 'tt0106489', 'tt0109361', 'tt0109443', 'tt0109783', 'tt0106965', 'tt0110074', 'tt0107286', 'tt0107302', 'tt0110265', 'tt0107497', 'tt0110678', 'tt0107756', 'tt0111003', 'tt0110971', 'tt0107969', 'tt0107983', 'tt0108002', 'tt0108065', 'tt0111127', 'tt0111194', 'tt0108255', 'tt0108328', 'tt0107688', 'tt0108358', 'tt0108399', 'tt0108515', 'tt0107002', 'tt0109403', 'tt0107225', 'tt0112651', 'tt0103639', 'tt0099348', 'tt0102926', 'tt0101414', 'tt0032910', 'tt0100405', 'tt0065421', 'tt0118001', 'tt0117381', 'tt0115837', 'tt0116275', 'tt0117060', 'tt0114048', 'tt0062952', 'tt0117107', 'tt0109374', 'tt0116827', 'tt0116508', 'tt0117998', 'tt0103926', 'tt0116629', 'tt0117737', 'tt0116778', 'tt0117218', 'tt0116040', 'tt0117333', 'tt0118113', 'tt0117913', 'tt0115530', 'tt0116320', 'tt0117438', 'tt0117008', 'tt0068646', 'tt0115736', 'tt0110693', 'tt0045152', 'tt0025316', 'tt0053604', 'tt0033870', 'tt0046250', 'tt0037059', 'tt0043014', 'tt0032484', 'tt0038787', 'tt0051658', 'tt0029843', 'tt0032599', 'tt0031679', 'tt0029947', 'tt0027893', 'tt0039152', 'tt0046414', 'tt0051459', 'tt0048491', 'tt0117039', 'tt0117473', 'tt0116421', 'tt0050798', 'tt0055277', 'tt0038166', 'tt0076538', 'tt0095016', 'tt0116242', 'tt0117802', 'tt0117665', 'tt0044863', 'tt0067992', 'tt0055018', 'tt0066808', 'tt0059243', 'tt0091763', 'tt0098627', 'tt0101761', 'tt0029992', 'tt2250194', 'tt0117318', 'tt0072081', 'tt0082340', 'tt0050825', 'tt0116209', 'tt0073486', 'tt0066921', 'tt0078788', 'tt0086190', 'tt0106308', 'tt0071562', 'tt0045061', 'tt0070735', 'tt0088247', 'tt0097441', 'tt0052311', 'tt0071315', 'tt0043456', 'tt0023969', 'tt0105695', 'tt0056218', 'tt0100436', 'tt0101921', 'tt0066206', 'tt0038355', 'tt0078841', 'tt0084503', 'tt0087553', 'tt0049223', 'tt0064115', 'tt0087884', 'tt0116589', 'tt0116953', 'tt0082010', 'tt0085159', 'tt0106262', 'tt0078767', 'tt0090655', 'tt0056869', 'tt0051418', 'tt0101492', 'tt0074258', 'tt0083722', 'tt0087800', 'tt0115495', 'tt0117057', 'tt0119791', 'tt0117477', 'tt0099423', 'tt0079945', 'tt0102975', 'tt0098382', 'tt0088170', 'tt0092007', 'tt0077766', 'tt0116695', 'tt0093822', 'tt0117038', 'tt0117364', 'tt0067959', 'tt0119115', 'tt0120550', 'tt0120414', 'tt0119141', 'tt0118548', 'tt0120434', 'tt0119008', 'tt0119951', 'tt0115964', 'tt0119528', 'tt0118972', 'tt0119381', 'tt0119229', 'tt0120032', 'tt0120383', 'tt0119809', 'tt0120190', 'tt0120394', 'tt0118787', 'tt0120034', 'tt0116334', 'tt0119654', 'tt0118884', 'tt0119896', 'tt0119086', 'tt0119051', 'tt0120102', 'tt0119174', 'tt0119123', 'tt0120399', 'tt0118647', 'tt0120402', 'tt0118842', 'tt0116631', 'tt0120029', 'tt0119324', 'tt0118900', 'tt0119527', 'tt0119978', 'tt0120201', 'tt0107282', 'tt0120382', 'tt0120483', 'tt0118583', 'tt0118698', 'tt0119715', 'tt0120222', 'tt0120255', 'tt0117994', 'tt0119925', 'tt0119314', 'tt0119396', 'tt0119485', 'tt0118715', 'tt0118566', 'tt0118539', 'tt0120696', 'tt0119099', 'tt0118956', 'tt0120008', 'tt0118747', 'tt0119822', 'tt0119594', 'tt0120890', 'tt0120793', 'tt0119049', 'tt0124295', 'tt0120738', 'tt0120749', 'tt0120632', 'tt0120765', 'tt0120213', 'tt0120906', 'tt0120211', 'tt0120800', 'tt01207 ...

# %% [raw]
# from multiprocessing import Pool
# import requests
# from bs4 import BeautifulSoup
#
# base_url = 'http://quotes.toscrape.com/page/'
#
# all_urls = list()
#
# def generate_urls():
#     for i in range(1,11):
#         all_urls.append(base_url + str(i))
#
# def scrape(url):
#     res = requests.get(url)
#     print(res.status_code, res.url)
#
# generate_urls()
#
# p = Pool(10)
# p.map(scrape, all_urls)
# p.terminate()
# p.join()

# %%
from multiprocessing import Pool
import requests
from bs4 import BeautifulSoup

base_url = 'http://www.imdb.com/title/'

all_urls = []
votes={}

def generate_urls():
    for i in ids:
        all_urls.append(base_url + str(i))
    
def scrape(url):    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find("span", {"class": "sc-7ab21ed2-1 jGRxWM"})
    print(a, url.split("/")[-2])
    votes[url.split("/")[-1]]=a  
   

generate_urls()

p = Pool(10)
p.map(scrape, all_urls)
p.terminate()
p.join()
# Out:
# NoneNone  NonetitletitleNone
#
# None title titletitle
#
#
# None titleNone
#  title
# None title
# NoneNone  titletitle
#
# None title
# None title
# None title
# None title
# NoneNone  titletitle
#
# None title
# None title
# None titleNoneNone
#   titletitle
#
# None title
# NoneNoneNone   titletitletitle
#
#
# None titleNone
#  title
# None titleNone
#  title
# None title
# None title
# None titleNoneNone
#   titletitle
#
# None title
# None title
# None title
# None Nonetitle
# title
# None title
# None title
# None title
# None title
# None title
# NoneNone  titletitle
# None
# None  titletitle
#
# None title
# NoneNone title
# title
# None title
# None title
# None titleNone
#  title
# None title
# None title
# None title
# None title
# None title
# None titleNone
#  title
# None title
# None title
# None title
# None title
# None title
# None title
# NoneNone  titletitle
#
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# NoneNone  titletitle
#
# None title
# None title
# None title
# None titleNone
#  title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# NoneNone  titletitle
#
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None title
# None Nonetitle
# title
# None title
# None title
# None title
# None Nonetitle
# title
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-7:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 25>()
#      22 generate_urls()
#      24 p = Pool(10)
# ---> 25 p.map(scrape, all_urls)
#      26 p.terminate()
#      27 p.join()
#
# File ~/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/anaconda3/envs/condaenv/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~/anaconda3/envs/condaenv/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/tmp/ipykernel_30072/2766442069.py", line 15, in scrape
#     response = requests.get(url)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 237, in resolve_redirects
#     resp = self.send(
#   File "/home/piegarroni/anaconda3/envs/condaenv/lib/python3.9/site-packages/requests/sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]

# %%
print(votes)

# %%
import requests, shutil
from bs4 import BeautifulSoup as bs
import threading


# code adapted from:
# https://github.com/chavarera/python-mini-projects/blob/master/projects/XKCD_downloader/xkcd_dowloader.py
def get_issue(issue_number):
    
    url = "http://www.imdb.com/title/"+ str(issue_number)

    response = requests.get(url)

    #Checking if we can fetch the url or not
    if response.status_code ==200:
        soup = bs(response.content, 'html.parser')
        image_link = soup.find_all('img')[2]['src']
        image_name = image_link.split('/')[-1]
        image_url = "https:" + image_link
        r = requests.get(image_url, stream=True)
        if r.status_code == 200:
            #This ensures the image file is loaded correctly
            r.raw.decode_content = True

            # Creating the image file
            with open(image_name, 'wb') as f:
                shutil.copyfileobj(r.raw, f)

            print('Image successfully Downloaded: ', image_name)
        else:
            print('Image Couldn\'t be retreived')
    else:
        print("Issue number {} is invalid".format(issue_number))



## FA -2 ###############################################

class myThread(threading.Thread): #we inherit from Thread class
  
    def __init__(self, issue): 
        
        threading.Thread.__init__(self) #we call the initialization of Thread
        self.issue = issue 
        
    #We need to override the run method of Thread
    # This is the function that will be called by the thread method start
    def run(self): 
        for _ in range(10):
            get_issue(self)

m = myThread(2366)
m.start() #use .start() to start a new thread. If you use .run() the method will not be executed in a different thread.
m.join()
print('done')
########################################################

# %%
urls=[]
votes=[]

# drop nan ids!!!!!!!!!!
for i in metas['imdb_id']:
    #print(i) 
    urls.append('http://www.imdb.com/title/'+i)
    response = requests.get('http://www.imdb.com/title/'+i)
    soup = BeautifulSoup(response.text, "html.parser")
    a = soup.find("span", {"class": "sc-7ab21ed2-1 jGRxWM"})
    votes.append(a)
# Out:
# KeyboardInterrupt

# %%
print(len(metas), len(votes))

# %%
metas['rating']=pd.Series(votes)

# %%
print(metas.info())
